# %%
from datetime import datetime

import pymongo
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sbn
from google.cloud import bigquery
from google.oauth2 import service_account
import statistics
from statistics import mean

# %%
DB_NAME = "sample_supplies"
COLLECTION = "sales"

# %%
client = pymongo.MongoClient("mongodb+srv://sebas1501:Avaya123!@cluster0.sozyzki.mongodb.net/?retryWrites=true&w=majority", server_api = pymongo.server_api.ServerApi('1'))

# %%
db = client[DB_NAME]

# %%
col = db[COLLECTION]

# %% [markdown]
# # QUERYS INICIALES

# %%
col.find_one({})
# Out:
# {'_id': ObjectId('5bd761dcae323e45a93ccfe8'),
#  'saleDate': datetime.datetime(2015, 3, 23, 21, 6, 49, 506000),
#  'items': [{'name': 'printer paper',
#    'tags': ['office', 'stationary'],
#    'price': Decimal128('40.01'),
#    'quantity': 2},
#   {'name': 'notepad',
#    'tags': ['office', 'writing', 'school'],
#    'price': Decimal128('35.29'),
#    'quantity': 2},
#   {'name': 'pens',
#    'tags': ['writing', 'office', 'school', 'stationary'],
#    'price': Decimal128('56.12'),
#    'quantity': 5},
#   {'name': 'backpack',
#    'tags': ['school', 'travel', 'kids'],
#    'price': Decimal128('77.71'),
#    'quantity': 2},
#   {'name': 'notepad',
#    'tags': ['office', 'writing', 'school'],
#    'price': Decimal128('18.47'),
#    'quantity': 2},
#   {'name': 'envelopes',
#    'tags': ['stationary', 'office', 'general'],
#    'price': Decimal128('19.95'),
#    'quantity': 8},
#   {'name': 'envelopes',
#    'tags': ['stationary', 'office', 'general'],
# ...

# %%
#revision de datos de fecha de los documentos
col.distinct("saleDate")
# Out:
# [datetime.datetime(2013, 1, 1, 4, 28, 58, 762000),
#  datetime.datetime(2013, 1, 1, 20, 27, 40, 389000),
#  datetime.datetime(2013, 1, 1, 23, 21, 17, 91000),
#  datetime.datetime(2013, 1, 2, 1, 17, 12, 861000),
#  datetime.datetime(2013, 1, 2, 2, 34, 42, 505000),
#  datetime.datetime(2013, 1, 2, 9, 57, 48, 238000),
#  datetime.datetime(2013, 1, 2, 14, 20, 52, 712000),
#  datetime.datetime(2013, 1, 2, 20, 36, 22, 549000),
#  datetime.datetime(2013, 1, 2, 23, 48, 1, 806000),
#  datetime.datetime(2013, 1, 3, 8, 38, 58, 629000),
#  datetime.datetime(2013, 1, 4, 0, 23, 27, 466000),
#  datetime.datetime(2013, 1, 4, 11, 35, 37, 493000),
#  datetime.datetime(2013, 1, 4, 16, 36, 12, 479000),
#  datetime.datetime(2013, 1, 6, 1, 14, 19, 899000),
#  datetime.datetime(2013, 1, 6, 21, 7, 19, 482000),
#  datetime.datetime(2013, 1, 7, 8, 47, 8, 843000),
#  datetime.datetime(2013, 1, 7, 12, 32, 40, 344000),
#  datetime.datetime(2013, 1, 7, 23, 17, 15, 373000),
# ...

# %%
# Counting all documents
# MongoDB equivalent: count({})
# SQL equivalent: SELECT COUNT(*) FROM airbnb
col.count_documents({})
# Out:
# 5000

# %%
# Specifying equality condition
# SQL equivalent: SELECT * FROM airbnb WHERE _id = "5bd761dcae323e45a93ccfe8"
col.find({"storeLocation": "Denver"})[0]
# Out:
# {'_id': ObjectId('5bd761dcae323e45a93ccfe8'),
#  'saleDate': datetime.datetime(2015, 3, 23, 21, 6, 49, 506000),
#  'items': [{'name': 'printer paper',
#    'tags': ['office', 'stationary'],
#    'price': Decimal128('40.01'),
#    'quantity': 2},
#   {'name': 'notepad',
#    'tags': ['office', 'writing', 'school'],
#    'price': Decimal128('35.29'),
#    'quantity': 2},
#   {'name': 'pens',
#    'tags': ['writing', 'office', 'school', 'stationary'],
#    'price': Decimal128('56.12'),
#    'quantity': 5},
#   {'name': 'backpack',
#    'tags': ['school', 'travel', 'kids'],
#    'price': Decimal128('77.71'),
#    'quantity': 2},
#   {'name': 'notepad',
#    'tags': ['office', 'writing', 'school'],
#    'price': Decimal128('18.47'),
#    'quantity': 2},
#   {'name': 'envelopes',
#    'tags': ['stationary', 'office', 'general'],
#    'price': Decimal128('19.95'),
#    'quantity': 8},
#   {'name': 'envelopes',
#    'tags': ['stationary', 'office', 'general'],
# ...

# %%
result=col.find({"saleDate": datetime(2013, 1, 10, 1, 10, 15, 493000)})[0]

# %%
col.find({"_id": ObjectId('5bd761dcae323e45a93ccfe8')})[0]
# Out:
# {'_id': ObjectId('5bd761dcae323e45a93ccfe8'),
#  'saleDate': datetime.datetime(2015, 3, 23, 21, 6, 49, 506000),
#  'items': [{'name': 'printer paper',
#    'tags': ['office', 'stationary'],
#    'price': Decimal128('40.01'),
#    'quantity': 2},
#   {'name': 'notepad',
#    'tags': ['office', 'writing', 'school'],
#    'price': Decimal128('35.29'),
#    'quantity': 2},
#   {'name': 'pens',
#    'tags': ['writing', 'office', 'school', 'stationary'],
#    'price': Decimal128('56.12'),
#    'quantity': 5},
#   {'name': 'backpack',
#    'tags': ['school', 'travel', 'kids'],
#    'price': Decimal128('77.71'),
#    'quantity': 2},
#   {'name': 'notepad',
#    'tags': ['office', 'writing', 'school'],
#    'price': Decimal128('18.47'),
#    'quantity': 2},
#   {'name': 'envelopes',
#    'tags': ['stationary', 'office', 'general'],
#    'price': Decimal128('19.95'),
#    'quantity': 8},
#   {'name': 'envelopes',
#    'tags': ['stationary', 'office', 'general'],
# ...

# %%
df = pd.json_normalize(result)

# %%
df
# Out:
#                    saleDate storeLocation purchaseMethod  customer.age
# 0   2014-03-31 16:02:06.624        Austin         Online            71
# 1   2013-03-20 16:36:39.112     San Diego         Online            61
# 2   2017-07-13 07:13:43.675        Denver       In store            70
# 3   2017-02-06 11:18:38.404        Denver       In store            60
# 4   2016-07-10 09:35:56.729       Seattle       In store            60
# ..                      ...           ...            ...           ...
# 927 2017-11-10 00:17:46.358        Denver       In store            60
# 928 2017-01-11 01:31:55.384     San Diego         Online            75
# 929 2016-08-17 09:31:04.467       Seattle       In store            63
# 930 2015-04-22 08:31:40.113      New York         Online            65
# 931 2013-10-06 22:39:37.868        Denver       In store            62
#
# [932 rows x 4 columns]

# %%
credentials = service_account.Credentials.from_service_account_file("./javeriana-dataprep.json", scopes = ["https://www.googleapis.com/auth/cloud-platform"])

# %%
client = bigquery.Client(credentials = credentials, project = credentials.project_id)

# %%
#Crear dataset para el grupo
dataset= bigquery.Dataset('javeriana-dataprep.GrupoDanielaStevenSebastian')

# %%
dataset.location='US'

# %%
dataset= client.create_dataset(dataset)

# %%
#Filtro por satisfaction
result4 = col.find({"customer.satisfaction": {"$gte":0}}, {"_id": 0,"saleDate":1, "storeLocation": 1, "purchaseMethod": 1, "customer.age": 1,"customer.satisfaction":1})

# %%
result4[0]
# Out:
# {'saleDate': datetime.datetime(2015, 3, 23, 21, 6, 49, 506000),
#  'storeLocation': 'Denver',
#  'customer': {'age': 42, 'satisfaction': 4},
#  'purchaseMethod': 'Online'}

# %%
df4 = pd.json_normalize(result4)

# %%
df4
# Out:
#                     saleDate storeLocation purchaseMethod  customer.age  \
# 0    2015-03-23 21:06:49.506        Denver         Online            42
# 1    2015-08-25 10:01:02.918       Seattle          Phone            50
# 2    2017-06-22 09:54:14.185        Denver       In store            51
# 3    2015-02-23 09:53:59.343       Seattle       In store            45
# 4    2017-12-03 18:39:48.253        London       In store            40
# ...                      ...           ...            ...           ...
# 4995 2016-01-20 17:29:10.225        Austin       In store            45
# 4996 2014-11-29 10:09:41.573        Denver       In store            47
# 4997 2017-12-25 07:02:51.283        Denver       In store            29
# 4998 2013-12-07 11:06:25.510        Denver         Online            59
# 4999 2014-08-18 06:25:49.739      New York         Online            33
#
#       customer.satisfaction
# 0                         4
# 1                         5
# ...

# %%
df4["customer.satisfaction"]=df4["customer.satisfaction"].astype('float64')
df4["customer.age"]=df4["customer.age"].astype('float64')

# %%
df4.sort_values("customer.satisfaction", ascending= False)
# Out:
#                     saleDate storeLocation purchaseMethod  customer.age  \
# 3812 2016-06-02 06:11:35.282        Denver       In store          42.0
# 1261 2013-01-24 22:16:54.160      New York          Phone          22.0
# 2927 2013-03-16 01:47:38.479        London       In store          33.0
# 1256 2013-02-04 22:01:15.086        London       In store          47.0
# 2179 2016-10-25 08:56:31.651     San Diego          Phone          50.0
# ...                      ...           ...            ...           ...
# 937  2014-06-30 19:49:36.022        Denver       In store          69.0
# 4164 2016-04-23 06:25:17.078      New York         Online          49.0
# 423  2015-05-07 01:17:13.835        Austin       In store          45.0
# 4637 2014-11-08 17:30:41.938       Seattle       In store          52.0
# 3798 2014-06-20 17:10:03.516       Seattle          Phone          37.0
#
#       customer.satisfaction
# 3812                    5.0
# 1261                    5.0
# ...

# %%
fecha=(pd.array(df4["saleDate"].dt.year)).tolist()

# %%
type(año)
# Out:
# list

# %%
df4["Fecha"]=año

# %%
df1["items"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'items'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1.value_counts("purchaseMethod")
# Out:
# purchaseMethod
# In store    2252
# Online      1268
# Phone        489
# dtype: int64

# %%
df4
# Out:
#                     saleDate storeLocation purchaseMethod  customer.age  \
# 0    2015-03-23 21:06:49.506        Denver         Online          42.0
# 1    2015-08-25 10:01:02.918       Seattle          Phone          50.0
# 2    2017-06-22 09:54:14.185        Denver       In store          51.0
# 3    2015-02-23 09:53:59.343       Seattle       In store          45.0
# 4    2017-12-03 18:39:48.253        London       In store          40.0
# ...                      ...           ...            ...           ...
# 4995 2016-01-20 17:29:10.225        Austin       In store          45.0
# 4996 2014-11-29 10:09:41.573        Denver       In store          47.0
# 4997 2017-12-25 07:02:51.283        Denver       In store          29.0
# 4998 2013-12-07 11:06:25.510        Denver         Online          59.0
# 4999 2014-08-18 06:25:49.739      New York         Online          33.0
#
#       customer.satisfaction
# 0                       4.0
# 1                       5.0
# ...

# %%
df_grouped3 = df4.groupby(["storeLocation","Fecha"]).agg({"customer.age": "mean","customer.satisfaction":"mean","storeLocation":"count"})

# %%
df_grouped3["customer.satisfaction"]=round(df_grouped3["customer.satisfaction"],2)

# %%
df_grouped3["Promedio_edad"]=round(df_grouped3["Promedio_edad"],2)

# %%
dateparse = lambda x: datetime.strptime(x, "%Y")

# %%
df3["Fecha"]=df3["Fecha"].astype('str').apply(dateparse)

# %%
df3.dtypes
# Out:
# saleDate                 datetime64[ns]
# storeLocation                    object
# purchaseMethod                   object
# customer.age                    float64
# customer.satisfaction           float64
# año                               int64
# Fecha                             int64
# dtype: object

# %%
df_grouped3.columns=['Promedio_edad','Promedio_Satisfaccion','CantidadCompras']

# %%
df_grouped3
# Out:
#                      Promedio_edad  Promedio_Satisfaccion  CantidadCompras
# storeLocation Fecha
# Austin        2013           44.34                   3.85              143
#               2014           45.38                   3.80              134
#               2015           46.94                   3.80              121
#               2016           45.99                   3.80              135
#               2017           43.90                   3.60              143
# Denver        2013           44.33                   3.74              289
#               2014           45.47                   3.90              298
#               2015           46.16                   3.73              343
#               2016           45.18                   3.81              313
#               2017           45.35                   3.83              306
# London        2013           43.02                   3.84              164
# ...

# %%
# Creating the job config
job_config = bigquery.LoadJobConfig(
    schema = [
        # Supported datatypes: https://cloud.google.com/bigquery/docs/reference/standard-sql/data-types
        bigquery.SchemaField("storeLocation", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("Fecha", bigquery.enums.SqlTypeNames.INT64),
        bigquery.SchemaField("Promedio_edad", bigquery.enums.SqlTypeNames.FLOAT64),
        bigquery.SchemaField("Promedio_Satisfaccion", bigquery.enums.SqlTypeNames.FLOAT64),
        bigquery.SchemaField("CantidadCompras", bigquery.enums.SqlTypeNames.INT64)
    ],
    # Drod and re-create table, if exist
    write_disposition = "WRITE_TRUNCATE",
)

# %%
BQ_TABLE_NAME = "GrupoDanielaStevenSebastian.taller_tabla1"

# %%
# Sending the job to BigQuery
job = client.load_table_from_dataframe(
    df_grouped3, BQ_TABLE_NAME, job_config = job_config
)

job.result()
# Out:
# LoadJob<project=javeriana-dataprep, location=US, id=d16d10ed-fe01-4c49-8cb9-e5148937a661>

# %%
table = client.get_table(BQ_TABLE_NAME)

print("Loaded {} rows and {} columns to {}".format(table.num_rows, len(table.schema), BQ_TABLE_NAME))
# Out:
# Loaded 30 rows and 5 columns to GrupoDanielaStevenSebastian.taller_tabla1

# %%
#Filtro por edad
result2 = col.find({"customer.age": {"$gte": 30}}, {"_id": 0, "storeLocation": 1,"items.price":1})

result3 = col.find({"customer.age": {"$lt": 30}}, {"_id": 0, "storeLocation": 1,"items.price":1})

# %%
df2 = pd.json_normalize(result2)
df3 = pd.json_normalize(result3)

# %%
df2=df2.rename(columns={'items':'CompraAdulto'})
df3=df3.rename(columns={'items':'CompraJoven'})

# %%
df2
# Out:
#                                            CompraAdulto storeLocation
# 0     [{'price': 40.01}, {'price': 35.29}, {'price':...        Denver
# 1     [{'price': 8.05}, {'price': 28.31}, {'price': ...       Seattle
# 2     [{'price': 30.08}, {'price': 24.68}, {'price':...        Denver
# 3     [{'price': 20.08}, {'price': 23.08}, {'price':...       Seattle
# 4     [{'price': 127.59}, {'price': 17.6}, {'price':...        London
# ...                                                 ...           ...
# 4187  [{'price': 23.4}, {'price': 13.29}, {'price': ...        Denver
# 4188  [{'price': 22.52}, {'price': 28.21}, {'price':...        Austin
# 4189  [{'price': 63.23}, {'price': 13.39}, {'price':...        Denver
# 4190                [{'price': 33.15}, {'price': 6.83}]        Denver
# 4191  [{'price': 24.12}, {'price': 27.1}, {'price': ...      New York
#
# [4192 rows x 2 columns]

# %%
resultado=([]) 
for x in range(len(df2)):
    compra=df2["CompraAdulto"][x]
    df1 = pd.DataFrame(compra)
    df1['price']=df1['price'].astype('str').astype('float64')
    resultado.append(round(df1.sum().tolist()[0],2))

resultado1=([]) 
for x in range(len(df3)):
    compra=df3["CompraJoven"][x]
    df1 = pd.DataFrame(compra)
    df1['price']=df1['price'].astype('str').astype('float64')
    resultado1.append(round(df1.sum().tolist()[0],2))

# %%
df2["CompraAdulto"]=resultado
df3["CompraJoven"]=resultado1

# %%
df2
# Out:
#       CompraAdulto storeLocation
# 0           269.79        Denver
# 1          1137.31       Seattle
# 2           942.28        Denver
# 3           297.59       Seattle
# 4          1527.13        London
# ...            ...           ...
# 4187         63.28        Denver
# 4188        336.52        Austin
# 4189        184.73        Denver
# 4190         39.98        Denver
# 4191        750.00      New York
#
# [4192 rows x 2 columns]

# %%
df_grouped = df2.groupby(["storeLocation"]).agg({"CompraAdulto": "mean"})
df_grouped1 = df3.groupby(["storeLocation"]).agg({"CompraJoven": "mean"})

# %%
df_grouped1
# Out:
#                CompraJoven
# storeLocation
# Austin          577.814742
# Denver          625.996288
# London          559.874851
# New York        639.481512
# San Diego       525.856308
# Seattle         614.186599

# %%
df_merge=pd.merge(df_grouped,df_grouped1,on="storeLocation")

# %%
df_merge['CompraAdulto']=round(df_merge['CompraAdulto'],2)
df_merge['CompraJoven']=round(df_merge['CompraJoven'],2)

# %%
df_merge
# Out:
#                CompraAdulto  CompraJoven
# storeLocation
# Austin               656.42       577.81
# Denver               595.90       626.00
# London               646.11       559.87
# New York             618.69       639.48
# San Diego            679.55       525.86
# Seattle              615.97       614.19

# %%
# Creating the job config
job_config = bigquery.LoadJobConfig(
    schema = [
        # Supported datatypes: https://cloud.google.com/bigquery/docs/reference/standard-sql/data-types
        bigquery.SchemaField("storeLocation", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("CompraAdulto", bigquery.enums.SqlTypeNames.FLOAT64),
        bigquery.SchemaField("CompraJoven", bigquery.enums.SqlTypeNames.FLOAT64),

    ],
    # Drod and re-create table, if exist
    write_disposition = "WRITE_TRUNCATE",
)

# %%
BQ_TABLE_NAME = "GrupoDanielaStevenSebastian.taller_tabla2"

# %%
# Sending the job to BigQuery
job = client.load_table_from_dataframe(
    df_merge, BQ_TABLE_NAME, job_config = job_config
)

job.result()
# Out:
# LoadJob<project=javeriana-dataprep, location=US, id=ec3d174a-f0e8-440e-b0d7-67cec6d07381>

# %%
table = client.get_table(BQ_TABLE_NAME)

print("Loaded {} rows and {} columns to {}".format(table.num_rows, len(table.schema), BQ_TABLE_NAME))
# Out:
# Loaded 6 rows and 3 columns to GrupoDanielaStevenSebastian.taller_tabla2

# %%
#Filtro por fecha --"la empresa a partir de 2014 realizó un cambio de estrategias comerciales necesita saber "
result1 = col.find({"saleDate": {"$gte": datetime(2012, 1, 1)}}, {"_id": 0, "storeLocation": 1, "purchaseMethod": 1,"customer.gender":1,"couponUsed":1})

# %%
result1[1]
# Out:
# {'storeLocation': 'Seattle',
#  'customer': {'gender': 'M'},
#  'couponUsed': False,
#  'purchaseMethod': 'Phone'}

# %%
df = pd.json_normalize(result1)

# %%
df=df.rename(columns={'storeLocation':'Tienda'})

# %%
df
# Out:
#      storeLocation  couponUsed purchaseMethod customer.gender
# 0           Denver        True         Online               M
# 1          Seattle       False          Phone               M
# 2           Denver       False       In store               M
# 3          Seattle       False       In store               F
# 4           London       False       In store               M
# ...            ...         ...            ...             ...
# 4995        Austin       False       In store               F
# 4996        Denver       False       In store               F
# 4997        Denver       False       In store               M
# 4998        Denver       False         Online               M
# 4999      New York       False         Online               M
#
# [5000 rows x 4 columns]

# %%
df_grouped = df.groupby(["storeLocation","purchaseMethod","customer.gender","couponUsed"]).agg({"storeLocation": "count"})

# %%
df_grouped=df_grouped.rename(columns={'storeLocation':'Transacciones'})

# %%
df_grouped=df_grouped.reset_index()

# %%
df_grouped
# Out:
#    storeLocation purchaseMethod customer.gender  couponUsed  Transacciones
# 0         Austin       In store               F       False            177
# 1         Austin       In store               F        True             14
# 2         Austin       In store               M       False            172
# 3         Austin       In store               M        True             15
# 4         Austin         Online               F       False            104
# ..           ...            ...             ...         ...            ...
# 66       Seattle         Online               M        True             13
# 67       Seattle          Phone               F       False             57
# 68       Seattle          Phone               F        True              5
# 69       Seattle          Phone               M       False             74
# 70       Seattle          Phone               M        True              9
#
# [71 rows x 5 columns]

# %%
df_grouped=df_grouped.rename(columns={'customer.gender':'Genero'})

# %%
df_grouped
# Out:
#    storeLocation purchaseMethod Genero  couponUsed  Transacciones
# 0         Austin       In store      F       False            177
# 1         Austin       In store      F        True             14
# 2         Austin       In store      M       False            172
# 3         Austin       In store      M        True             15
# 4         Austin         Online      F       False            104
# ..           ...            ...    ...         ...            ...
# 66       Seattle         Online      M        True             13
# 67       Seattle          Phone      F       False             57
# 68       Seattle          Phone      F        True              5
# 69       Seattle          Phone      M       False             74
# 70       Seattle          Phone      M        True              9
#
# [71 rows x 5 columns]

# %%
# Creating the job config
job_config = bigquery.LoadJobConfig(
    schema = [
        # Supported datatypes: https://cloud.google.com/bigquery/docs/reference/standard-sql/data-types
        bigquery.SchemaField("storeLocation", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("purchaseMethod", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("Genero", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("couponUsed", bigquery.enums.SqlTypeNames.BOOL),
        bigquery.SchemaField("Transacciones", bigquery.enums.SqlTypeNames.FLOAT64),

    ],
    # Drod and re-create table, if exist
    write_disposition = "WRITE_TRUNCATE",
)

# %%
BQ_TABLE_NAME = "GrupoDanielaStevenSebastian.taller_tabla3"

# %%
# Sending the job to BigQuery
job = client.load_table_from_dataframe(
    df_grouped, BQ_TABLE_NAME, job_config = job_config
)

job.result()
# Out:
# LoadJob<project=javeriana-dataprep, location=US, id=66b21001-ff7c-4d77-9435-a0a25a4a59a3>

# %%
table = client.get_table(BQ_TABLE_NAME)

print("Loaded {} rows and {} columns to {}".format(table.num_rows, len(table.schema), BQ_TABLE_NAME))
# Out:
# Loaded 71 rows and 5 columns to GrupoDanielaStevenSebastian.taller_tabla3
